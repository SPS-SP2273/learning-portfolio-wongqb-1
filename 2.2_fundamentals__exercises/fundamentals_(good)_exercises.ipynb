# %% [markdown]
# <div style="text-align:left;font-size:2em"><span style="font-weight:bolder;font-size:1.25em">SP2273 | Learning Portfolio</span><br><br><span style="font-weight:bold;color:darkred">Fundamentals (Good) Exercises</span></div>

# %%
user_input = input('Please provide me with a name?')
print('How you doin '+user_input+'!')
# Out:
# How you doin Wong!

# %%
name = input('Please enter your name!')
age = input('Please enter your age!')
print('My name is '+ name + ' and I am '+ age+ ' years old.')
# Out:
# My name is Wong and I am 67 years old.

# %%
pi = 3.141592653589793
print(f'The value of pi to 2 decimal places is: {pi:.2f}')
print(f'The value of pi to 3 decimal places is: {pi:.3f}')
print(f'The value of pi to 4 decimal places is: {pi:.4f}')
# Out:
# The value of pi to 2 decimal places is: 3.14
# The value of pi to 3 decimal places is: 3.142
# The value of pi to 4 decimal places is: 3.1416

# %%
fruit = ['Apple', 'Banana', 'Orange']
price = [0.99, 0.59, 1.29]
for i in range(len(fruit)):
    print(f'{fruit[i]:<10}${price[i]:>5,.2f}') 
print()
print(f'{'':*^10}${'':*^5}')
# Out:
# Apple     $ 0.99
# Banana    $ 0.59
# Orange    $ 1.29
#
# **********$*****

# %%
scoreString = input('Enter the student\'s score:')
try:
    score = int(scoreString)
    if (score>=70) and (score<=100) and (score>=0):
        grade = 'A'
        print(f'The student\'s letter grade is: {grade}')
    elif (score >=50) and (score<=100) and (score>=0):
        grade = 'B'
        print(f'The student\'s letter grade is: {grade}')
    elif (score >= 35) and (score<=100) and (score>=0):
        grade = 'C'
        print(f'The student\'s letter grade is: {grade}')
    elif (score >= 0) and (score<=100):
        grade = 'Fail'
        print(f'The student\'s letter grade is: {grade}')
    else:
        print('Not a valid score.')
except:
    print("Something went wrong.")
# Out:
# Something went wrong.

# %%
def factorial(n):
    if n < 0:
        return "Invalid input"
    elif n == 0:
        return 1
    else:
        result = 1
        for number in range(1, n+1):
            result *= number
        return result


print(factorial(5))   # Testing, expected output: 120
print(factorial(-1))  # Testing, expected output: Invalid input
# Out:
# 120
# Invalid input

# %% [markdown]
# Note: `!dir` prints the current directory. Essentially, anything with `!` will be sent to the shell.
