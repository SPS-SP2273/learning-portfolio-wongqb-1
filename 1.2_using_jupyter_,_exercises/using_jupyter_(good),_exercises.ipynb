# %% [markdown]
# <div style="text-align:left;font-size:2em"><span style="font-weight:bolder;font-size:1.25em">SP2273 | Learning Portfolio</span><br><br><span style="font-weight:bold;color:darkred">Using Jupyter (Good), Exercises</span></div>

# %%
while True:
    print('*', end='')

    # Press the stop button on the left to invoke KeyboardInterrupt
# Out:
# **************************************************************************************************************************************************************************************************************************************************************************************************************************************************************************************************************************************************************************************************************************************************************************************************************************************************************************************************************************************************************************************************************************************************************************************************************************************************************************************************************************************************************************************************************************************************************************************************************************************************************************************************************************************************************************************************************************************************************************************************************************************************************************************************************************************************************************************************************************************************************************************************************************************************************************************************************************************************************************************************************************************************************************************************************************************************************************************************************************************************************************************************************************************************************************************************************************************************************************************************************************************************************************************************************************************************************************************************************************************************************************************************************************************************************************************************************************************************************************************************************************************************************************************************************************************************************************************************************************************************************************************************************************************************************************************************************************************************************************************************************************************************************************************************************************************************************************************************************************************************************************************************************************************************************************************************************************************************************************************************************************************************************************************************************************************************************** ...
# ---------------------------------------------------------------------------
# KeyboardInterrupt                         Traceback (most recent call last)
# Cell In[1], line 2
#       1 while True:
# ----> 2     print('*', end='')
#
# File c:\Users\wongqb\miniconda3\Lib\site-packages\IPython\core\interactiveshell.py:3053, in InteractiveShell._tee.<locals>.write(data, *args, **kwargs)
#    3051 def write(data, *args, **kwargs):
#    3052     """Write data to both the original destination and the capture dictionary."""
# -> 3053     result = original_write(data, *args, **kwargs)
#    3054     if any(
#    3055         [
#    3056             self.display_pub.is_publishing,
#    (...)   3059         ]
#    3060     ):
#    3061         return result
#
# File c:\Users\wongqb\miniconda3\Lib\site-packages\ipykernel\iostream.py:679, in OutStream.write(self, string)
#     677 # only touch the buffer in the IO thread to avoid races
#     678 with self._buffer_lock:
# --> 679     self._buffers[frozenset(parent.items())].write(string)
#     680 if is_child:
#     681     # mp.Pool cannot be trusted to flush promptly (or ever),
#     682     # and this helps.
#     683     if self._subprocess_flush_pending:
#
# KeyboardInterrupt:

# %%
print = 'PRINT'
print('Hello World')
# Restart the kernel by pressing Restart on top of VSCode
# Out:
# ---------------------------------------------------------------------------
# TypeError                                 Traceback (most recent call last)
# Cell In[3], line 2
#       1 print = 'PRINT'
# ----> 2 print('Hello World')
#       3 # Restart the kernel by pressing Restart on top of VSCode
#
# TypeError: 'str' object is not callable

# %%
print('Hello World')
# Out:
# Hello World

# %%
squares = [i**2 for i in range(10)]
print(squares)
# Out:
# [0, 1, 4, 9, 16, 25, 36, 49, 64, 81]

# %%
squares = list()
for i in range(10):
    squares.append(i**2)
print(squares)
# Out:
# [0, 1, 4, 9, 16, 25, 36, 49, 64, 81]

# %%
# %timeit squares = [i**2 for i in range(10)]
# Out:
# 819 ns ± 22.8 ns per loop (mean ± std. dev. of 7 runs, 1,000,000 loops each)

# %%
# %%timeit
squares = list()
for i in range(10):
    squares.append(i**2)
# Out:
# 1.09 μs ± 21.9 ns per loop (mean ± std. dev. of 7 runs, 1,000,000 loops each)

# %% [markdown]
# ## Footnotes
