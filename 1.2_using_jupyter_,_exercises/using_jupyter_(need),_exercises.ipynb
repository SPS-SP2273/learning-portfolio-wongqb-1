# %% [markdown]
# <div style="text-align:left;font-size:2em"><span style="font-weight:bolder;font-size:1.25em">SP2273 | Learning Portfolio</span><br><br><span style="font-weight:bold;color:darkred">Using Jupyter (Need), Exercises</span></div>

# %% [markdown]
# ## 1 Quadratic Equations

# %% [markdown]
# ### Introduction

# %% [markdown]
# ![](https://upload.wikimedia.org/wikipedia/commons/thumb/f/f8/Polynomialdeg2.svg/2560px-Polynomialdeg2.svg.png)
# *(Image from the [Wikipedia page on Quadratic equations](https://en.wikipedia.org/wiki/Quadratic_equation))*
#
# The general form of a quadratic equation is: $ax^2 + bx + c = 0$

# %% [markdown]
# ### Solutions

# %% [markdown]
# Provided $a \neq 0$, we can use an elementary algebraic method called [completing the square](https://en.wikipedia.org/wiki/Completing_the_square) to show that a quadratic equation has the following solution: $x = \frac{-b \pm \sqrt{b^2 - 4ac}}{2a}$

# %% [markdown]
# ### Discriminant

# %% [markdown]
# The quantity $\Delta = b^2 - 4ac$ is called the **discriminant** of the equation and decides the nature of its solutions. The table below shows the various possibilities:
# |Discriminants|Roots|
# |-------------|-----|
# |$\Delta = b^2 - 4ac = 0 | A single solution of $-b/(2a)$|
# |$\Delta = b^2 - 4ac > 0 | Two distinct solutions |
# |$\Delta = b^2 - 4ac < 0 | No real solutions; both are complex|

# %% [markdown]
# 1. A Git repository is a "site for file sharing" for programmers of sorts where people can collaborate with each other without worrying about conflicting changes, and also to keep track of who changed what in the repository.
# 2. Git keeps track of ___changes___ in the files in our repository.
# 3. A commit is an action to save the changes that one chooses to save to the Git repository.
# 4. A push is an action to upload said changes to the repository in a server, typically GitHub.
# 5. A pull is an action to download any changes to the repository through the server so that one can work on it.
# 6. GitHub is the repository server, GitHub Desktop is the desktop client to access GitHub.

# %% [markdown]
# $$\begin{align*}
# \mu &= \frac{1}{n}\sum_{i = 1}^n x_i\\
# \sigma &= \sqrt{\frac{1}{n}\sum_{i = 1}^n (x_i - \mu)^2}\\
# r &= \dfrac{\sum_{i=1}^n (x_i - \mu_X)(y_i -\mu_Y)}{\sqrt{\sum_{i=1}^{n}(x_i - \mu_X)^2\sum_{i=1}^{n}(y_i - \mu_Y)^2}}
# \end{align*}$$
